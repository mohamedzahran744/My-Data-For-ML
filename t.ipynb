# %%
import secrets

# %%
secrets.token_hex(16)
# Out:
# 'c23aa61f80f08b993bf5cb03ac444fdf'

# %%
from utils.CustomerData import CustomerData
import pandas as pd 
from utils.config import preprocessor, forest_model

# %%
data = {
        "CreditScore": 650,
        "Geography": "France",
        "Gender": "Male",
        "Age": 35,
        "Tenure": 5,
        "Balance": 10000.50,
        "NumOfProducts": 2,
        "HasCrCard": 1,
        "IsActiveMember": 1,
        "EstimatedSalary": 50000.0
    }

# %%
data
# Out:
# {'CreditScore': 650,
#  'Geography': 'France',
#  'Gender': 'Male',
#  'Age': 35,
#  'Tenure': 5,
#  'Balance': 10000.5,
#  'NumOfProducts': 2,
#  'HasCrCard': 1,
#  'IsActiveMember': 1,
#  'EstimatedSalary': 50000.0}

# %%
new = pd.DataFrame([data])

# %%
preprocessed= preprocessor.transform(new)

# %%
forest_model.predict(preprocessed)
# Out:
# array([0])
