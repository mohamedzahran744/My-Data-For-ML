# %%
import plotly.express as px

# %%
px.data.__all__
# Out:
# ['carshare',
#  'election',
#  'election_geojson',
#  'experiment',
#  'gapminder',
#  'iris',
#  'medals_wide',
#  'medals_long',
#  'stocks',
#  'tips',
#  'wind']

# %%
df_tips = px.data.tips()
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.histogram(data_frame=df_tips, x='total_bill', color='smoker', color_discrete_sequence=['black', 'green'], nbins=50)

# %%
# bar plot
px.bar(data_frame=df_tips, x='smoker', color='sex', barmode='group')

# %%
px.histogram(data_frame=df_tips, x='smoker', color='sex', barmode='group')

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.histogram(data_frame=df_tips, x='total_bill', y='tip', color='sex', facet_col='day', marginal='box')

# %%
import plotly.figure_factory as ff

hist_data = df_tips.total_bill.to_list()
ff.create_distplot([hist_data], ['total_bill'], bin_size=2, show_rug=False, show_hist=True, show_curve=False, colors=['green'])
